# %%
import tensorflow as tf
import numpy as np
import matplotlib.pyplot as plt
from tensorflow.keras.layers import Input, Dense, Dropout, Flatten, Conv2D, MaxPooling2D
from tensorflow.keras.models import Model

# %%
fashion_mnist = tf.keras.datasets.fashion_mnist
(X_train, y_train), (X_test, y_test) = fashion_mnist.load_data()
X_train = X_train/255.0
X_test = X_test/255.0
print(f"Training feature size: {X_train.shape}")
# Out:
# Training feature size: (60000, 28, 28)

# %%
# Convolution expect input size as 3D - height x width x color
# Fashion MNIST dataset is 2D, convert it to 3D 
X_train = np.expand_dims(X_train, -1)
X_test = np.expand_dims(X_test, -1)
print(f"New Training feature size: {X_train.shape}")
# Out:
# New Training feature size: (60000, 28, 28, 1)

# %%
# Total size of samples
print(f"samples: {X_train[0].shape}")
# Out:
# samples: (28, 28, 1)

# %%
# Number of classes
K = len(set(y_train))
print(f"Number of classes: {K}")
# Out:
# Number of classes: 10

# %%
# Building the model using functional API
i = Input(shape=X_train[0].shape)
x = Conv2D(32, (3, 3), strides=2, activation='relu')(i)
x = Conv2D(64, (3, 3), strides=2, activation='relu')(x)
x = Conv2D(128, (3, 3), strides=2, activation="relu")(x)
x = Flatten()(x)
x = Dropout(0.3)(x)
x = Dense(128, activation="relu")(x)
x = Dropout(0.3)(x)
x = Dense(K, activation="softmax")(x)

model = Model(i, x)

# %%
model.compile(
    optimizer='adam',
    loss="sparse_categorical_crossentropy",
    metrics=["accuracy"]
)

r = model.fit(X_train,y_train, validation_data=(X_test,y_test), epochs = 10)
# Out:
# WARNING:tensorflow:TensorFlow GPU support is not available on native Windows for TensorFlow >= 2.11. Even if CUDA/cuDNN are installed, GPU will not be used. Please use WSL2 or the TensorFlow-DirectML plugin.
# Epoch 1/10
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 10s 5ms/step - accuracy: 0.7880 - loss: 0.5766 - val_accuracy: 0.8390 - val_loss: 0.4180
# Epoch 2/10
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 8s 4ms/step - accuracy: 0.8510 - loss: 0.3987 - val_accuracy: 0.8583 - val_loss: 0.3743
# Epoch 3/10
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 8s 5ms/step - accuracy: 0.8693 - loss: 0.3477 - val_accuracy: 0.8716 - val_loss: 0.3407
# Epoch 4/10
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 8s 4ms/step - accuracy: 0.8813 - loss: 0.3169 - val_accuracy: 0.8819 - val_loss: 0.3145
# Epoch 5/10
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 9s 5ms/step - accuracy: 0.8893 - loss: 0.2917 - val_accuracy: 0.8906 - val_loss: 0.3020
# Epoch 6/10
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 8s 4ms/step - accuracy: 0.8983 - loss: 0.2714 - val_accuracy: 0.8873 - val_loss: 0.3148
# Epoch 7/10
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 8s 4ms/step - accuracy: 0.9047 - loss: 0.2552 - val_accuracy: 0.8913 - val_loss: 0.3000
# Epoch 8/10
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 8s 4ms/step - accuracy: 0.9091 - loss: 0.2421 - val_accuracy: 0.8999 - val_loss: 0.2861
# Epoch 9/10
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 8s 4ms/step - accuracy: 0.9124 - loss: 0.2306 - val_accuracy: 0.8980 - val_loss: 0.2840
# Epoch 10/10
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 8s 4ms/step - accuracy: 0.9168 - loss: 0.2193 - val_accuracy: 0.8951 - val_loss: 0.2986

# %%
plt.plot(r.history['loss'],label='training_loss')
plt.plot(r.history['val_loss'], label='validation_loss')
plt.legend()

# %% [markdown]
# Model is overfitting as validation loss is higher than the training loss

# %%
plt.plot(r.history['accuracy'], label='training_accuracy')
plt.plot(r.history['val_accuracy'], label='validation_accuracy')
plt.legend()

# %%
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay

y_pred = model.predict(X_test)
y_pred = np.argmax(y_pred, axis=1)
print(y_test)
print(y_pred)
# Out:
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step
# [9 2 1 ... 8 1 5]
# [9 2 1 ... 8 1 5]

# %%
# Labels
labels = '''T-shirts/top
Trouser
Pullover
Dress
Coat
Sandal
Shirt
Sneaker
Bag
Ankle boot'''.split()

# %%
cm = confusion_matrix(y_test, y_pred)
disp = ConfusionMatrixDisplay(confusion_matrix=cm)
disp.plot(cmap=plt.cm.Blues, values_format="d")

# %%
misclassified_idx = np.where(y_pred != y_test)[0]
i = np.random.choice(misclassified_idx)
plt.imshow(X_test[i], cmap='gray')
plt.title(f"True Label: {labels[y_test[i]]}, Predicted Label: {labels[y_pred[i]]}")
# Out:
# Text(0.5, 1.0, 'True Label: Dress, Predicted Label: Pullover')
